859231708768,1.114890129129746,-0.47527290880670553,1.323038157613542,1.450715678323438,0.7156034810420091,0.006512502744865653,-0.04734484985562597,0.7108224158023101,1.5264979152457498,-0.006445980773778242,1.192276375800248,0.382511704647533,-0.3891771295167188,0.4263593992834985],"y":[-0.14390429920309317,1.3394892025525014,0.046143768355824906,0.5238307025160422,-1.195836923680431,-1.1196760400752768,1.4534819371156962,0.7802668553400796,-0.5865946352953202,-1.0348694042791002,0.5248363450199661,1.9036108901100972,0.456922164877447,-1.3586336872272309,1.998874830884497,-0.7892136658835549,-0.7141143269118381,-0.1721863236343253,1.1969012893520166,-0.39634498310011623,0.349770602981039,0.4638422709741826,0.33718649137361006,1.9927243859127066,-0.23248770124713697,-0.7509268591210431,-1.5588853177770954,0.389261255150865,0.2818002281254669,-0.35427366918726483,0.5216921155135978,-0.09442852160927968,-0.8255169302830976,0.044776461985857656,1.5117333390555503,0.8769703644736634,-0.2736706598491258,1.1869338937119724,0.9787604576982538,1.5988990096017834,0.2936499246266835,1.4406366434745015,0.7959291821302102,1.7288330972139125,0.5931554972302633,0.8473497357039254,-1.5472886259411345,1.3024534456969754,-0.7516429957472129,1.8725316657809135,0.2676988783216779,0.6873277372733378,-1.0980858708286902,-1.074683621383597,1.3356813216804633,0.23211376551363386,-0.26853807278888653,0.4671094668639248,0.7462291111461198,-0.21648105454228372,0.11320710284589154,0.5456011716743066,1.000534399720389,0.33721126360053766,-1.127972657004079,1.2780463867467915,0.8640764 ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=3)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
print('MAE',mean_absolute_error(y_test,y_pred))
print('MSE',mean_squared_error(y_test,y_pred))
print('r2score',r2_score(y_test,y_pred))
# Out:
# MAE 52.53675814565256
# MSE 3884.3463161465706
# r2score 0.5066047808062502

# %%
x=np.linspace(-5,5,10)
y=np.linspace(-5,5,10)
xGrid,yGrid=np.meshgrid(y,x)
final=np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T
z_final=lr.predict(final).reshape(10,10)
z=z_final

# %%
fig=px.scatter_3d(df,x='features0',y='features1',z='target')
fig.add_trace(go_Surface(x =x,y =y,z =z))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 fig=px.scatter_3d(df,x='features0',y='features1',z='target')
# ----> 2 fig.add_trace(go_Surface(x =x,y =y,z =z))
#       3 plt.show()
#
# NameError: name 'go_Surface' is not defined

# %%
lr.coef_
# Out:
# array([62.16879713, -3.88437215])

# %%
lr.intercept_
# Out:
# -11.593385469410052
