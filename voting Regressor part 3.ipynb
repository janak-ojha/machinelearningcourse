# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

# %%
df=pd.read_csv('iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
new_df=df.iloc[:,1:]

# %%
new_df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
new_df['Species']=encoder.fit_transform(new_df['Species'])

# %%
new_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
df=new_df[new_df['Species']!=0][['SepalLengthCm','PetalLengthCm','Species']]

# %%
df
# Out:
#      SepalLengthCm  PetalLengthCm  Species
# 50             7.0            4.7        1
# 51             6.4            4.5        1
# 52             6.9            4.9        1
# 53             5.5            4.0        1
# 54             6.5            4.6        1
# ..             ...            ...      ...
# 145            6.7            5.2        2
# 146            6.3            5.0        2
# 147            6.5            5.2        2
# 148            6.2            5.4        2
# 149            5.9            5.1        2
#
# [100 rows x 3 columns]

# %%
plt.scatter(df['SepalLengthCm'],df['PetalLengthCm'],c=df['Species'],cmap='winter')

# %%
df=df.sample(100)
df_train=df.iloc[60:,:].sample(20)
df_val=df.iloc[60:80,:].sample(5)
df_test=df.iloc[80:,:].sample(5)

# %%
x_test=df_val.iloc[:,0:2]
y_test=df_val.iloc[:,-1]

# %%
df_bag=df_train.sample(8,replace=True)
x=df_bag.iloc[:,0:2]
y=df_bag.iloc[:,-1]

# %%
df_bag
# Out:
#      SepalLengthCm  PetalLengthCm  Species
# 64             5.6            3.6        1
# 85             6.0            4.5        1
# 145            6.7            5.2        2
# 140            6.7            5.6        2
# 119            6.0            5.0        2
# 140            6.7            5.6        2
# 119            6.0            5.0        2
# 85             6.0            4.5        1

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
from mlxtend.plotting import plot_decision_regions

# %%
dc=DecisionTreeClassifier()

# %%
evaluate(dc,x,y)
# Out:
# C:\Users\JANAK RAJ OJHA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# accuracyscr 1.0

# %%
def evaluate(clf,x,y):
    clf.fit(x,y)
    plot_tree(clf)
    plot_decision_regions(x.values,y.values,clf=clf,legend=2)
    y_pred=clf.predict(x_test)
    print('accuracyscr',accuracy_score(y_test,y_pred))

# %%
df1=df_train.sample(8,replace=True)
x1=df1.iloc[:,0:2]
y1=df1.iloc[:,-1]

# %%
evaluate(dc,x1,y1)
# Out:
# C:\Users\JANAK RAJ OJHA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# accuracyscr 1.0

# %%
df2=df_train.sample(8,replace=True)
x=df2.iloc[:,0:2]
y=df2.iloc[:,-1]

# %%
evaluate(dc,x,y)
# Out:
# C:\Users\JANAK RAJ OJHA\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# accuracyscr 1.0

# %%
df1=pd.read_csv('iris.csv')

# %%
df1=df1.sample(10)

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 80    81            5.5           2.4            3.8           1.1
# 113  114            5.7           2.5            5.0           2.0
# 34    35            4.9           3.1            1.5           0.1
# 119  120            6.0           2.2            5.0           1.5
# 48    49            5.3           3.7            1.5           0.2
# 135  136            7.7           3.0            6.1           2.3
# 73    74            6.1           2.8            4.7           1.2
# 56    57            6.3           3.3            4.7           1.6
# 69    70            5.6           2.5            3.9           1.1
# 125  126            7.2           3.2            6.0           1.8
#
#              Species
# 80   Iris-versicolor
# 113   Iris-virginica
# 34       Iris-setosa
# 119   Iris-virginica
# 48       Iris-setosa
# 135   Iris-virginica
# 73   Iris-versicolor
# 56   Iris-versicolor
# 69   Iris-versicolor
# ...

# %%
df1.sample(2,replace=True,axis=1)
# Out:
#      SepalWidthCm  PetalWidthCm
# 80            2.4           1.1
# 113           2.5           2.0
# 34            3.1           0.1
# 119           2.2           1.5
# 48            3.7           0.2
# 135           3.0           2.3
# 73            2.8           1.2
# 56            3.3           1.6
# 69            2.5           1.1
# 125           3.2           1.8

# %%
df1.sample(8,replace=True).sample(2,replace=True,axis=1)
# Out:
#      SepalWidthCm  SepalLengthCm
# 48            3.7            5.3
# 113           2.5            5.7
# 48            3.7            5.3
# 80            2.4            5.5
# 69            2.5            5.6
# 56            3.3            6.3
# 125           3.2            7.2
# 113           2.5            5.7
