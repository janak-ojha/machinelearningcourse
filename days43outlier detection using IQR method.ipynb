# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('placementcsv.csv')
df.sample(5)
# Out:
#      cgpa  placement_exam_marks  placed
# 691  7.32                  14.0       0
# 930  6.94                   7.0       1
# 111  6.48                  33.0       0
# 740  6.21                  74.0       1
# 581  6.57                  25.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])
plt.show()
# Out:
# C:\Users\JANAK RAJ OJHA\AppData\Local\Temp\ipykernel_20340\2931562495.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# C:\Users\JANAK RAJ OJHA\AppData\Local\Temp\ipykernel_20340\2931562495.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(df['placement_exam_marks'])
# Out:
# <AxesSubplot: >

# %%
percentile25=df['placement_exam_marks'].quantile(0.25)
percentile75=df['placement_exam_marks'].quantile(0.75)

# %%
percentile75
# Out:
# 44.0

# %%
iqr=percentile75-percentile25

# %%
upper_limit=percentile75+1.5*iqr
lower_limit=percentile25-1.5*iqr

# %%
print('upperlimit',upper_limit)
print('lowerlimit',lower_limit)
# Out:
# upperlimit 84.5
# lowerlimit -23.5

# %%
df[(df['placement_exam_marks']>84.5)|(df['placement_exam_marks']<-23.5)]
# Out:
#      cgpa  placement_exam_marks  placed
# 9    7.75                  94.0       1
# 40   6.60                  86.0       1
# 61   7.51                  86.0       0
# 134  6.33                  93.0       0
# 162  7.80                  90.0       0
# 283  7.09                  87.0       0
# 290  8.38                  87.0       0
# 311  6.97                  87.0       1
# 324  6.64                  90.0       0
# 630  6.56                  96.0       1
# 685  6.05                  87.0       1
# 730  6.14                  90.0       1
# 771  7.31                  86.0       1
# 846  6.99                  97.0       0
# 917  5.95                 100.0       0

# %%
newdf=df[df['placement_exam_marks']<upper_limit]

# %%
newdf
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [985 rows x 3 columns]

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])
plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(newdf['placement_exam_marks'])
plt.subplot(2,2,4)
sns.boxplot(newdf['placement_exam_marks'])
# Out:
# C:\Users\JANAK RAJ OJHA\AppData\Local\Temp\ipykernel_20340\900424288.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# C:\Users\JANAK RAJ OJHA\AppData\Local\Temp\ipykernel_20340\900424288.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
newdf2=df.copy()
newdf2=np.where(
          newdf2['placement_exam_marks']>upper_limit,
          ,
              np.where(
              newdf2['placement_exam_marks']<lower_limit,
              lowerlimit,
              newdf2['placement_exam_marks']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 4
#       1 newdf2=df.copy()
#       2 newdf2=np.where(
#       3           newdf2['placement_exam_marks']>upper_limit,
# ----> 4           upperlimit,
#       5               np.where(
#       6               newdf2['placement_exam_marks']<lower_limit,
#       7               lowerlimit,
#       8               newdf2['placement_exam_marks']))
#
# NameError: name 'upperlimit' is not defined

# %%
newdf2.shape
# Out:
# (1000,)

# %%
plt.figure(figsize=(16,7))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])
plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(newdf2['placement_exam_marks'])
plt.subplot(2,2,4)
sns.boxplot(newdf2['placement_exam_marks'])
# Out:
# C:\Users\JANAK RAJ OJHA\AppData\Local\Temp\ipykernel_20340\2454421668.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[82], line 8
#       5 sns.boxplot(df['placement_exam_marks'])
#       7 plt.subplot(2,2,3)
# ----> 8 sns.distplot(newdf2['placement_exam_marks'])
#       9 plt.subplot(2,2,4)
#      10 sns.boxplot(newdf2['placement_exam_marks'])
#
# ...
